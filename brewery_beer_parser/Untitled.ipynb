# %%
pip install selenium
# Out:
# ...
#      |████████████████████████████████| 904 kB 3.5 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.1.1; however, version 21.2.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.7/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd

# %%
! pwd
# Out:
# /Users/ksdkalluri/BeerRatingsAnalysis

# %%
driver = webdriver.Chrome('/Users/ksdkalluri/BeerRatingsAnalysis/chromedriver')

# %%
driver.get(f'https://untappd.com/treehousebrewco/beer')

# %%
df = pd.read_csv('/Users/ksdkalluri/Desktop/gender_match_status.csv', header=0)
df
# Out:
#                           ppi_gender           ehr_gender match_status
# 0                    SexAtBirth_Male               FEMALE     no_match
# 1                    SexAtBirth_Male                 MALE        match
# 2                    SexAtBirth_Male  No matching concept  missing_ehr
# 3                    SexAtBirth_Male                OTHER     no_match
# 4                    SexAtBirth_Male              UNKNOWN     no_match
# 5                    SexAtBirth_Male            AMBIGUOUS     no_match
# 6                    SexAtBirth_Male   Gender unspecified     no_match
# 7                    SexAtBirth_Male       Gender unknown     no_match
# 8                  SexAtBirth_Female               FEMALE        match
# 9                  SexAtBirth_Female                 MALE     no_match
# 10                 SexAtBirth_Female  No matching concept  missing_ehr
# 11                 SexAtBirth_Female                OTHER     no_match
# ...

# %%
df.pivot(index='match_status', columns = ['ehr_gender', 'ppi_gender'])
df
# Out:
#                           ppi_gender           ehr_gender match_status
# 0                    SexAtBirth_Male               FEMALE     no_match
# 1                    SexAtBirth_Male                 MALE        match
# 2                    SexAtBirth_Male  No matching concept  missing_ehr
# 3                    SexAtBirth_Male                OTHER     no_match
# 4                    SexAtBirth_Male              UNKNOWN     no_match
# 5                    SexAtBirth_Male            AMBIGUOUS     no_match
# 6                    SexAtBirth_Male   Gender unspecified     no_match
# 7                    SexAtBirth_Male       Gender unknown     no_match
# 8                  SexAtBirth_Female               FEMALE        match
# 9                  SexAtBirth_Female                 MALE     no_match
# 10                 SexAtBirth_Female  No matching concept  missing_ehr
# 11                 SexAtBirth_Female                OTHER     no_match
# ...

# %%
df.order_by()m
