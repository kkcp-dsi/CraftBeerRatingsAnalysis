# %%
import pandas as pd

# %%
import glob
import os

# %%
path = r'brewery_beers'
extension = '.csv'
csv_list = []
       
for root, dirs, files in os.walk(path):
    for filename in files:
        if os.path.splitext(filename)[-1] == extension:
            csv_list.append(os.path.join(root, filename))

# %%
frames = []
for file in csv_list:
    state_and_brewery = file.split('/')
    df = pd.read_csv(file, index_col=False)
    df.insert(1, 'brewery', state_and_brewery[2].split('.')[0])
    df.insert(2, 'state', state_and_brewery[2])
    df['state'] = state_and_brewery[1]
    df['brewery'] = state_and_brewery[2].split('.')[0]
    df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
    frames.append(df)

# %%
result = pd.concat(frames)

# %%
result
# Out:
#                   brewery       state  \
# 0   Missouri_Beer_Company    Missouri
# 1   Missouri_Beer_Company    Missouri
# 2   Missouri_Beer_Company    Missouri
# 3   Missouri_Beer_Company    Missouri
# 4   Missouri_Beer_Company    Missouri
# ..                    ...         ...
# 20         Eskes_Brew_Pub  New_Mexico
# 21         Eskes_Brew_Pub  New_Mexico
# 22         Eskes_Brew_Pub  New_Mexico
# 23         Eskes_Brew_Pub  New_Mexico
# 24         Eskes_Brew_Pub  New_Mexico
#
#                                              beer_url  \
# 0   https://untappd.com//b/missouri-beer-company-r...
# 1   https://untappd.com//b/missouri-beer-company-e...
# 2   https://untappd.com//b/missouri-beer-company-k...
# 3   https://untappd.com//b/missouri-beer-company-e...
# 4   https://untappd.com//b/missouri-beer-company-m...
# ..                                                ...
# 20  https://untappd.com//b/eske-s-brew-pub-and-eat...
# 21  https://untappd.com//b/eske-s-brew-pub-eatery-...
# 22  https://untappd.com//b/eske-s-brew-pub-eatery-...
# 23  https://untappd.com//b/eske-s-brew-pub-and-eat...
# 24  https://untappd.com//b/eske-s-brew-pub-eatery-...
#
#                   beer_name                     beer_style  \
# 0               Red Rye IPA                      IPA - Rye
# 1            Eastern MO IPA                  IPA - Session
# 2                    Kolsch                         Kölsch
# 3         English Dark Mild                   Mild - Other
# 4   Mango Hibiscus Pale Ale            Pale Ale - American
# ..                      ...                            ...
# 20               EskeWeizen            Wheat  - Hefeweizen
# 21            Mesa Pale Ale            Pale Ale - American
# 22                Black Cat                   Lager - Dark
# 23                Rat Queen        IPA - Imperial / Double
# 24           Special Bitter  Extra Special / Strong Bitter
#
#                                             beer_desc  beer_abv beer_ibu  \
# 0   An American Red IPA made with a large amount o...  5.9% ABV   65 IBU
# 1   Our version of the New England style IPA. Thre...  5.5% ABV   37 IBU
# 2   A clean, crisp, German Ale. Delicately balance...  4.5% ABV   19 IBU
# 3   A dark, low gravity, malt focused British sess...  4.2% ABV   15 IBU
# 4   An American Pale ale with a twist. Hibiscus fl...    5% ABV   35 IBU
# ..                                                ...       ...      ...
# 20  This German-Style Wheat  pours hazy with suspe...  5.6% ABV   25 IBU
# 21                                                NaN   N/A ABV  N/A IBU
# 22  Actually a black lager, but that's not on the ...   N/A ABV  N/A IBU
# 23                                                NaN   N/A ABV  N/A IBU
# 24                                                NaN  5.4% ABV  N/A IBU
#
#     beer_average_rating beer_num_ratings beer_added
# 0                  3.56              856   08/28/16
# 1                  3.61              797   03/18/17
# 2                  3.54              744   09/04/16
# 3                  3.61              764   09/24/16
# 4                  3.50              599   08/28/16
# ..                  ...              ...        ...
# 20                 3.61               27   05/13/17
# 21                 3.34               22   12/18/11
# 22                 3.20               21   06/17/11
# 23                 4.06               20   06/27/15
# 24                 3.43               18   11/01/12
#
# [124922 rows x 11 columns]

# %%
result.to_csv('all_beers.csv')

# %%
breweries_path = r'Breweries'

extension = '.csv'
breweries_list = []

for root, dirs, files in os.walk(breweries_path):
    for filename in files:
        if os.path.splitext(filename)[-1] == extension:
            breweries_list.append(os.path.join(root, filename))

# %%
len(breweries_list)
# Out:
# 51

# %%
beer_frames = []
for file in breweries_list:
    df = pd.read_csv(file, index_col=False)
    df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
    beer_frames.append(df)

# %%
beer_result = pd.concat(beer_frames)

# %%
beer_result
# Out:
#                                            obdb_id  \
# 0                    5-alarm-brewing-co-lake-mills
# 1                             515-brewing-co-clive
# 2                           albia-brewing-co-albia
# 3                    alluvial-brewing-company-ames
# 4                        backroad-brewery-carlisle
# ..                                             ...
# 180                wild-wolf-brewing-co-nellysford
# 181                 wolf-hills-brewing-co-abingdon
# 182             wood-ridge-farm-brewery-lovingston
# 183                  woodstock-brewhouse-woodstock
# 184  young-veterans-brewing-company-virginia-beach
#
#                                name brewery_type  \
# 0                5 Alarm Brewing Co        micro
# 1                    515 Brewing Co        micro
# 2                  Albia Brewing Co      brewpub
# 3          Alluvial Brewing Company        micro
# 4                  BackRoad Brewery        micro
# ..                              ...          ...
# 180            Wild Wolf Brewing Co        micro
# 181           Wolf Hills Brewing Co        micro
# 182         Wood Ridge Farm Brewery        micro
# 183             Woodstock Brewhouse      brewpub
# 184  Young Veterans Brewing Company        micro
#
#                             street address_2  address_3            city  \
# 0                    211 W Main St       NaN        NaN      Lake Mills
# 1              7700 University Ave       NaN        NaN           Clive
# 2                  11 Benton Ave E       NaN        NaN           Albia
# 3                  3715 W 190th St       NaN        NaN            Ames
# 4                     90 School St       NaN        NaN        Carlisle
# ..                             ...       ...        ...             ...
# 180       2461 Rockfish Valley Hwy       NaN        NaN      Nellysford
# 181                 350 Park St SE       NaN        NaN        Abingdon
# 182               151 Old Ridge Rd       NaN        NaN      Lovingston
# 183                 123 E Court St       NaN        NaN       Woodstock
# 184  2505 Horse Pasture Rd Ste 104       NaN        NaN  Virginia Beach
#
#         state  county_province postal_code  ...   latitude tags  \
# 0        Iowa              NaN       50450  ...  43.419266  NaN
# 1        Iowa              NaN  50325-1271  ...  41.599992  NaN
# 2        Iowa              NaN  52531-2032  ...  41.027189  NaN
# 3        Iowa              NaN  50014-9316  ...        NaN  NaN
# 4        Iowa              NaN       50047  ...  41.498501  NaN
# ..        ...              ...         ...  ...        ...  ...
# 180  Virginia              NaN  22958-2306  ...        NaN  NaN
# 181  Virginia              NaN  24210-3314  ...  36.712325  NaN
# 182  Virginia              NaN  22949-2550  ...        NaN  NaN
# 183  Virginia              NaN  22664-1761  ...  38.881426  NaN
# 184  Virginia              NaN  23453-2988  ...        NaN  NaN
#
#                              brewery_id  average_rating  num_of_ratings  \
# 0    https://untappd.com/brewery/378685           3.845          1311.0
# 1     https://untappd.com/brewery/24774           3.845         46405.0
# 2     https://untappd.com/brewery/57547           3.396          2730.0
# 3    https://untappd.com/brewery/190226           3.973         43681.0
# 4        https://untappd.com/brewery/63           3.510          3169.0
# ..                                  ...             ...             ...
# 180    https://untappd.com/brewery/9546           3.471         78799.0
# 181    https://untappd.com/brewery/7775           3.631         15728.0
# 182  https://untappd.com/brewery/293897           3.503          5114.0
# 183  https://untappd.com/brewery/208741           3.650          7679.0
# 184   https://untappd.com/brewery/62944           3.644         48140.0
#
#      num_of_beers total_check_ins  unique_user_check_ins  \
# 0            90.0            1588                    432
# 1           129.0           67000                  11226
# 2             0.0            3392                   1216
# 3           260.0           54688                   8937
# 4             0.0            4166                   2139
# ..            ...             ...                    ...
# 180         115.0          101553                  38359
# 181         180.0           20753                   7675
# 182          78.0            6170                   1455
# 183          47.0            9542                   2339
# 184          43.0           68110                  19618
#
#      last_four_week_check_ins  \
# 0                          10
# 1                         205
# 2                           0
# 3                         200
# 4                           4
# ..                        ...
# 180                       105
# 181                        18
# 182                        63
# 183                        82
# 184                       290
#
#                                           brewery_desc
# 0    Our mission at 5 Alarm Brewing Company is to g...
# 1    Centrally located in the Des Moines metro area...
# 2                                            Show Less
# 3                                            Show Less
# 4    Established in 1996 in the county of LaPorte, ...
# ..                                                 ...
# 180  Wild Wolf Brewing Company is a brewery and res...
# 181  Wolf Hills Brewing Co. is a craft brewery loca...
# 182  We are a family farm brewery utilizing all loc...
# 183  Woodstock Brewhouse is a craft brewery in hist...
# 184  Veteran owned, operated and located in the hea...
#
# [5888 rows x 24 columns]

# %%
beer_result.to_csv('all_breweries.csv')
